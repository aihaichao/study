# %%
	368  export HIVE_SERVER2_THRIFT_PORT=8008
  369  export HIVE_SERVER2_THRIFT_BIND_HOST=localhost
  370  ./start-thriftserver.sh --master local
  371  cat  /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
  372  telnet localhost 8008
  373  yum install telnet
  374  telnet localhost 8008
  376  ps -ef|grep thrift
  377  kill 46657
  
  382  cd spark-2.1.0-bin-hadoop2.7
  383  ls
  384  vi test_spark.py
  385  python test_spark.py 
  386  vi test_spark.py
  387  ./bin/spark-submit --help
  392  ./bin/spark-submit --master local --py-files test_spark.py 
  393  ./bin/spark-submit --master local  test_spark.py 
  394  ./sbin/start-thriftserver.sh\ --master local  test_spark.py 
  395  ./sbin/start-thriftserver.sh--master local--hiveconf hive.server2.thrift.port=8008
  397  ./sbin/start-thriftserver.sh --master local --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0 test_spark.py 
  399  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out

  401  ./sbin/start-thriftserver.sh --master local --deploy-mode client --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0 test_spark.py 

  404  ./sbin/stop-thriftserver.sh
  405  ps -ef|grep thrift
  406  ./sbin/start-thriftserver.sh --master local --deploy-mode client --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0 test_spark.py 
  407  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
  408  ./sbin/stop-thriftserver.sh --help
  409  
  412  ./sbin/start-thriftserver.sh --master local[2] --deploy-mode client --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0 test_spark.py 
  413  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
  414  ./sbin/stop-thriftserver.sh 
  415  

  419  ./sbin/start-thriftserver.sh --help
  420  ./sbin/stop-thriftserver.sh 
  421  ./sbin/start-thriftserver.sh --master local[2]  --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0 test_spark.py 
  422  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
  423  ./sbin/stop-thriftserver.sh 
  424  vi test_spark.py 
 
  440  ./sbin/stop-thriftserver.sh 
  441  ./sbin/start-thriftserver.sh --help
  442  ./sbin/start-thriftserver.sh --master local --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0
  443  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
  444  ./sbin/stop-thriftserver.sh 
  
  445  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
  446  ./sbin/start-thriftserver.sh --master local --hiveconf hive.server2.thrift.port=8008 --hiveconf hive.server2.thrift.bind.host=0.0.0.0
  447  tail -f /root/Downloads/spark-2.1.0-bin-hadoop2.7/logs/spark-root-org.apache.spark.sql.hive.thriftserver.HiveThriftServer2-1-localhost.localdomain.out
